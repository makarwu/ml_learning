# %%
import numpy as np
import matplotlib.pyplot as plt

# assume we have some unit gaussian 10-D input data
D = np.random.randn(1000, 500)
hidden_layer_sizes = [500]*10
nonlinearities = ['tanh']*len(hidden_layer_sizes)

act = {'relu': lambda x:np.maximum(0, x), 'tanh': lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) * 0.01 # layer initialization

    H = np.dot(X, W) # matix multiply
    H = act[nonlinearities[i]](H) # nonlinearity
    Hs[i] = H # cache result on this layer

# look at the distribution at each layer
print('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i, H in Hs.items()]
layer_stds = [np.std(H) for i, H in Hs.items()]
for i, H in Hs.items():
    print('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))

# plot the means and deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i, H in Hs.items():
    plt.subplot(1, len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1, 1))
# Out:
# input layer had mean -0.004225 and std 0.999283
# hidden layer 1 had mean 0.000045 and std 0.213851
# hidden layer 2 had mean 0.000015 and std 0.047549
# hidden layer 3 had mean -0.000008 and std 0.010631
# hidden layer 4 had mean -0.000002 and std 0.002382
# hidden layer 5 had mean -0.000000 and std 0.000532
# hidden layer 6 had mean -0.000000 and std 0.000119
# hidden layer 7 had mean -0.000000 and std 0.000027
# hidden layer 8 had mean 0.000000 and std 0.000006
# hidden layer 9 had mean -0.000000 and std 0.000001
# hidden layer 10 had mean 0.000000 and std 0.000000

# %%
# assume we have some unit gaussian 10-D input data
D = np.random.randn(1000, 500)
hidden_layer_sizes = [500]*10
nonlinearities = ['tanh']*len(hidden_layer_sizes)

act = {'relu': lambda x:np.maximum(0, x), 'tanh': lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) * 1.0 # different layer initialization

    H = np.dot(X, W) # matix multiply
    H = act[nonlinearities[i]](H) # nonlinearity
    Hs[i] = H # cache result on this layer

# look at the distribution at each layer
print('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i, H in Hs.items()]
layer_stds = [np.std(H) for i, H in Hs.items()]
for i, H in Hs.items():
    print('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))

# plot the means and deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i, H in Hs.items():
    plt.subplot(1, len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1, 1))
# Out:
# input layer had mean 0.000569 and std 0.999111
# hidden layer 1 had mean -0.000364 and std 0.981884
# hidden layer 2 had mean 0.000358 and std 0.981637
# hidden layer 3 had mean 0.000363 and std 0.981734
# hidden layer 4 had mean 0.000621 and std 0.981680
# hidden layer 5 had mean -0.000376 and std 0.981404
# hidden layer 6 had mean 0.001600 and std 0.981550
# hidden layer 7 had mean 0.000262 and std 0.981637
# hidden layer 8 had mean -0.000033 and std 0.981773
# hidden layer 9 had mean 0.002052 and std 0.981746
# hidden layer 10 had mean 0.000583 and std 0.981590

# %%
# assume we have some unit gaussian 10-D input data
D = np.random.randn(1000, 500)
hidden_layer_sizes = [500]*10
nonlinearities = ['tanh']*len(hidden_layer_sizes)

act = {'relu': lambda x:np.maximum(0, x), 'tanh': lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in) # Xavier initialiuation

    H = np.dot(X, W) # matix multiply
    H = act[nonlinearities[i]](H) # nonlinearity
    Hs[i] = H # cache result on this layer

# look at the distribution at each layer
print('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i, H in Hs.items()]
layer_stds = [np.std(H) for i, H in Hs.items()]
for i, H in Hs.items():
    print('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))

# plot the means and deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i, H in Hs.items():
    plt.subplot(1, len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1, 1))
# Out:
# input layer had mean -0.000610 and std 1.000736
# hidden layer 1 had mean -0.000298 and std 0.627957
# hidden layer 2 had mean -0.000846 and std 0.486634
# hidden layer 3 had mean -0.000216 and std 0.408203
# hidden layer 4 had mean 0.001027 and std 0.357158
# hidden layer 5 had mean 0.001385 and std 0.319997
# hidden layer 6 had mean 0.000353 and std 0.294203
# hidden layer 7 had mean 0.000018 and std 0.271304
# hidden layer 8 had mean -0.000169 and std 0.252737
# hidden layer 9 had mean 0.000448 and std 0.238347
# hidden layer 10 had mean -0.000396 and std 0.226978

# %%
# assume we have some unit gaussian 10-D input data
D = np.random.randn(1000, 500)
hidden_layer_sizes = [500]*10
nonlinearities = ['tanh']*len(hidden_layer_sizes)

act = {'relu': lambda x:np.maximum(0, x), 'tanh': lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in/2) # He et al. 2015

    H = np.dot(X, W) # matix multiply
    H = act[nonlinearities[i]](H) # nonlinearity
    Hs[i] = H # cache result on this layer

# look at the distribution at each layer
print('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i, H in Hs.items()]
layer_stds = [np.std(H) for i, H in Hs.items()]
for i, H in Hs.items():
    print('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))

# plot the means and deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i, H in Hs.items():
    plt.subplot(1, len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1, 1))
# Out:
# input layer had mean 0.000509 and std 1.000515
# hidden layer 1 had mean -0.000723 and std 0.720282
# hidden layer 2 had mean -0.001191 and std 0.633628
# hidden layer 3 had mean 0.000632 and std 0.596489
# hidden layer 4 had mean 0.000116 and std 0.578335
# hidden layer 5 had mean 0.000642 and std 0.567588
# hidden layer 6 had mean 0.000591 and std 0.560958
# hidden layer 7 had mean 0.001514 and std 0.558633
# hidden layer 8 had mean 0.000873 and std 0.557024
# hidden layer 9 had mean 0.000332 and std 0.557658
# hidden layer 10 had mean -0.000153 and std 0.556386
